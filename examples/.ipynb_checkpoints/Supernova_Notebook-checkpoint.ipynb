# %% [markdown]
# ### Importing necessary libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from spextractor import Spextractor
import json
import csv
import os

# %% [markdown]
# ### Making .txt file from the .json file

# %%
json_file = '/home/rabbit/SpectralAnalysis_SNe/examples/ASASSN-14hr.json'
output_dir = '/home/rabbit/SpectralAnalysis_SNe/examples/processed/'
os.makedirs(output_dir, exist_ok=True)

with open(json_file, 'r') as f:
    data_structure = json.load(f)

# Loop over supernovae in JSON (usually one per file)
for sn_name, sn_data in data_structure.items():
    spectra_list = sn_data['spectra']
    
    redshift = sn_data.get('redshift', [{}])[0]

    times = np.array([float(spec['time']) for spec in spectra_list])
    idx = np.argmin(times)
    closest_spec = spectra_list[idx]
    selected_mjd = float(closest_spec['time'])
    print(f"{sn_name}: selected spectrum at MJD {selected_mjd}, z={redshift}")

    raw_data = closest_spec['data']
    data_array = np.array(raw_data, dtype=float)
    wavelength = data_array[:, 0]
    flux = data_array[:, 1]
    error = data_array[:, 2]

    mask = np.isclose(flux, error)
    if np.any(mask):
        error[mask] = 1e-20 

    dat_file = os.path.join(output_dir, f"{sn_name}.dat")
    clean_data = np.column_stack((wavelength, flux, error))
    np.savetxt(dat_file, clean_data, fmt='%.6e', header='wavelength flux error')

    meta_file = os.path.join(output_dir, f"{sn_name}_meta.json")
    meta_info = {'MJD': selected_mjd, 'redshift': redshift}
    with open(meta_file, 'w') as mf:
        json.dump(meta_info, mf, indent=2)

    print(f"{sn_name}: saved {dat_file} and metadata {meta_file}")
# Out:
# ASASSN-14hr: selected spectrum at MJD 56933.0, z={'value': '0.03362', 'source': '3,6,7,9'}
# ASASSN-14hr: saved /home/rabbit/SpectralAnalysis_SNe/examples/processed/ASASSN-14hr.dat and metadata /home/rabbit/SpectralAnalysis_SNe/examples/processed/ASASSN-14hr_meta.json

# %% [markdown]
# ### Photon Conserving Downsampling

# %%
'''target_bins = 1000  

wave_min, wave_max = wavelength.min(), wavelength.max()
edges = np.linspace(wave_min, wave_max, target_bins + 1) 

indices = np.digitize(wavelength, edges) - 1  
indices[indices == target_bins] = target_bins - 1  

flux_binned = np.zeros(target_bins)
error_binned = np.zeros(target_bins)
wavelength_binned = (edges[:-1] + edges[1:]) / 2  

for i in range(target_bins):
    mask = indices == i
    if np.any(mask):
        flux_binned[i] = flux[mask].sum()  
        error_binned[i] = np.sqrt(np.sum(error[mask]**2))  
    else:
        flux_binned[i] = 0.0
        error_binned[i] = 1e-20 

downsampled_file = '/home/rabbit/SpectralAnalysis_SNe/examples/ASASSN-14hr_downsampled.dat'
clean_downsampled = np.column_stack((wavelength_binned, flux_binned, error_binned))
np.savetxt(downsampled_file, clean_downsampled, fmt='%.6e', header='wavelength flux error')
print(f"Saved downsampled spectrum to {downsampled_file}")'''
# Out:
# 'target_bins = 1000  \n\nwave_min, wave_max = wavelength.min(), wavelength.max()\nedges = np.linspace(wave_min, wave_max, target_bins + 1) \n\nindices = np.digitize(wavelength, edges) - 1  \nindices[indices == target_bins] = target_bins - 1  \n\nflux_binned = np.zeros(target_bins)\nerror_binned = np.zeros(target_bins)\nwavelength_binned = (edges[:-1] + edges[1:]) / 2  \n\nfor i in range(target_bins):\n    mask = indices == i\n    if np.any(mask):\n        flux_binned[i] = flux[mask].sum()  \n        error_binned[i] = np.sqrt(np.sum(error[mask]**2))  \n    else:\n        flux_binned[i] = 0.0\n        error_binned[i] = 1e-20 \n\ndownsampled_file = \'/home/rabbit/SpectralAnalysis_SNe/examples/ASASSN-14hr_downsampled.dat\'\nclean_downsampled = np.column_stack((wavelength_binned, flux_binned, error_binned))\nnp.savetxt(downsampled_file, clean_downsampled, fmt=\'%.6e\', header=\'wavelength flux error\')\nprint(f"Saved downsampled spectrum to {downsampled_file}")'

# %% [markdown]
# ### Calculating Silicon Layer Velocities and pEWs

# %%
spectra_dir = '/home/rabbit/SpectralAnalysis_SNe/examples/processed/'  
metadata_dir = '/home/rabbit/SpectralAnalysis_SNe/examples/processed/'  
output_dir = '/home/rabbit/SpectralAnalysis_SNe/examples/results/'     
os.makedirs(output_dir, exist_ok=True)

sn_list = [f.replace('.dat','') for f in os.listdir(spectra_dir) if f.endswith('.dat')]

features_to_measure = ('Si II 6150A', 'Si II 5800A')

results_summary = []

for sn_name in sn_list:
    dat_file = os.path.join(spectra_dir, f"{sn_name}.dat")
    meta_file = os.path.join(metadata_dir, f"{sn_name}_meta.json")

    with open(meta_file, 'r') as f:
        meta = json.load(f)
    redshift = float(meta['redshift']['value'])
    mjd = float(meta['MJD'])
    print(f"\nProcessing {sn_name}: MJD={mjd}, z={redshift}")

    spex = Spextractor(dat_file, z=redshift, plot=True, log=True)

    spex.create_model(model_type='gpr', downsampling=3.0)

    spex.process(features_to_measure)

    sn_results = {'SN': sn_name, 'MJD': mjd, 'redshift': redshift}
    print("Measured Values:")
    for feat in features_to_measure:
        vel = spex.vel[feat]
        vel_err = spex.vel_err[feat]
        pew = spex.pew[feat]
        pew_err = spex.pew_err[feat]

        sn_results[f'{feat}_vel'] = vel
        sn_results[f'{feat}_vel_err'] = vel_err
        sn_results[f'{feat}_pEW'] = pew
        sn_results[f'{feat}_pEW_err'] = pew_err

        print(f"  {feat}: v = {vel:.2f} ± {vel_err:.2f} km/s, pEW = {pew:.2f} ± {pew_err:.2f} Å")

    results_summary.append(sn_results)

    fig, ax = spex.fig_ax
    plt.tight_layout()
    plot_file = os.path.join(output_dir, f"{sn_name}_spectrum.png")
    fig.savefig('Ia_example.png', dpi=300)
    plt.close(fig)  
    print(f"Saved plot: {plot_file}")
   
summary_file = os.path.join(output_dir, 'all_sne_results.csv')
df = pd.DataFrame(results_summary)
df.to_csv(summary_file, index=False)
print(f"\nSaved all results summary to {summary_file}")
# Out:
# Processing ASASSN-14hr: MJD=56933.0, z=0.03362
# Measured Values:
#   Si II 6150A: v = 11.82 ± 0.62 km/s, pEW = 105.23 ± 1.12 Å
#   Si II 5800A: v = 11.75 ± 1.00 km/s, pEW = 24.16 ± 0.92 Å
# Saved plot: /home/rabbit/SpectralAnalysis_SNe/examples/results/ASASSN-14hr_spectrum.png
#
# Saved all results summary to /home/rabbit/SpectralAnalysis_SNe/examples/results/all_sne_results.csv
# /tmp/ipykernel_34013/83805133.py:46: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()
